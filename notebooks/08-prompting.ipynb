# %%
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate
load_dotenv()
# Out:
# True

# %%
from langchain import chat_models
llm = chat_models.init_chat_model("openai:gpt-4o-mini", temperature=0)

# %%
template = """\
    # Instricciones para el asistente de IA

    Recuerda que hoy es {fecha_actual}

    ## Rol
    Eres un experto en marketing digital con 10 años de experiencia.

    ## Tarea
    Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.

    ## Texto del anuncio
    {texto_anuncio}

    ## Formato de salida
    - *Sugerencia 1:* [Tu primera sugerencia]
    - *Sugerencia 2:* [Tu segunda sugerencia]
    - *Sugerencia 3:* [Tu tercera sugerencia]
"""

# %%
from datetime import datetime

today = datetime.now().strftime("%Y-%m-%d")

prompt_template = PromptTemplate.from_template(
    partial_variables={
        "fecha_actual": today,
        "texto_anuncio": "Anuncio de Piñas"
    },
    template=template
)

# %%
prompt = prompt_template.format(fecha_actual="2026-01-14", texto_anuncio="Anuncio de amacas")
print(prompt)
# Out:
#     # Instricciones para el asistente de IA
#
#     Recuerda que hoy es 2026-01-14
#
#     ## Rol
#     Eres un experto en marketing digital con 10 años de experiencia.
#
#     ## Tarea
#     Analiza el siguiente texto de un anuncio y proporciona 3 sugerencias para mejorarlo, enfocandote en el llamado a la accion.
#
#     ## Texto del anuncio
#     Anuncio de amacas
#
#     ## Formato de salida
#     - *Sugerencia 1:* [Tu primera sugerencia]
#     - *Sugerencia 2:* [Tu segunda sugerencia]
#     - *Sugerencia 3:* [Tu tercera sugerencia]

# %% [markdown]
# **Jinja**

# %%
template = """\
    # You are a helpful that responds to the user's message.

    {% if name %}
    The user's name is {{ name }} and you can call them using the name
    {% endif -%}

    The user's message is: {{ message }}
    """
prompt_tempalte = PromptTemplate.from_template(template, template_format="jinja2")
prompt = prompt_tempalte.format(message="Hello, how are you?", name=None)
print(prompt)
# Out:
#     # You are a helpful that responds to the user's message.
#
#     The user's message is: Hello, how are you?
