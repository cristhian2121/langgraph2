# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-5-nano", temperature=1)

response = model.invoke("Donde murio cristobal colon")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Murió en Valladolid, Castilla y León, España, el 20 de mayo de 1506.

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("openai:gpt-4o-mini", temperature=0)

response = model.invoke("Donde murio cristobal colon")
response.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Murió en Valladolid, España, el 20 de mayo de 1506, mientras estaba al servicio de los Reyes Católicos.
